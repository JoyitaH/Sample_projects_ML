# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
veh = pd.read_csv("C:/Users/Joyita/Data_Science/Data/test car data.csv")

# %%
veh.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  milage/kmpl  \
# 0      Dealer       Manual      0           20
# 1      Dealer       Manual      0           18
# 2      Dealer       Manual      0           21
# 3      Dealer       Manual      0           22
# 4      Dealer       Manual      0           15
#
#   car condition (as per Kms_Driven)
# 0                               old
# 1                               old
# 2                               new
# 3                               new
# 4                               old

# %% [markdown]
# Inference:In this data sheet, we can see car condition and milage as per year and kms driven.

# %%
sns.catplot(x= "Selling_Price", y="Present_Price", data=veh)

# %% [markdown]
# Inference: by seeing this visualisation, we can see the difference between selling price and present price.

# %%
sns.catplot(x = "Transmission" , y= "Present_Price" , data= veh ,kind = "box")

# %% [markdown]
# Inference: 1.In this visualisation , we can observe that number of Manual cars is more as compared to Automatic.
#     2.we also observe new car have automactic transmission.

# %%
sns.catplot(x = "car condition (as per Kms_Driven)" , y= "milage/kmpl" , data= veh ,kind = "box" )

# %% [markdown]
# Inference: 1.In this visualisation , we can observe that number of old cars is more as compared to new car.
#
# 2. we also observe old car gives more milage as compared to new cars.
# 3.By seeing this visualisation we also see old car gives milage between 22 to 25 and new car gives milage between
#   21 to 23.

# %%
sns.catplot(x="car condition (as per Kms_Driven)", data = veh , kind="count")

# %% [markdown]
# Inference:1.In this , we can see number of new cars is approx 7.
#           2.we also observe count of old cars lies between o to 24.

# %%
sns.catplot(x="milage/kmpl", data=veh, kind="count")

# %% [markdown]
# Inference:In this plot we can see, most of cars gives milage 25 kmpl.
#           2. count of cars which gives 25kmpl milage is range from o to 7.

# %%
sns.set(style="whitegrid")
sns.distplot(veh["Selling_Price"])

# %%
sns.catplot(x = "Transmission" , data= veh ,kind = "count" , hue = "Fuel_Type")
plt.savefig("img_3")

# %% [markdown]
# Inference:1.In this,we can see more number of cars is manual and very less number of cars have CNG fuel type.
#           2.We also observe cars range between 0 to 16 have petrol fueltype, 0 to 10 have diesel fuel type and 0 to 1
#             have CNG fuel type.
#           3.Cars which have automatic transmission mostly use Petrol as Fuel

# %%
sns.boxenplot(data=veh, x="Year")

# %% [markdown]
# Inference: we can see most of car models is between 2013 to 2016.

# %%
sns.swarmplot(data=veh, x="Transmission", y="Year")

# %% [markdown]
# Inference:In this, we can see in 2015 maximum number of cars have manual transmission as compared to other years.

# %%
sns.boxplot(x = "Transmission" , y= "Present_Price" , data= veh , hue = "Fuel_Type" , order=["Automatic", "Manual"])

# %% [markdown]
# Inference:1.By seeing this we can observe that car ranges from 9 to 10.5 have diesel as Fuel_Type.
#           2.Cars renges from 4.1 to 7.2 have Petrol as Fuel_Type.

# %%
sns.catplot(x="Selling_Price", y="Transmission", data=veh, kind="violin")
plt.savefig("img_16")

# %% [markdown]
# Inference:1.by seeing this we can say that Manual transmission car selling price ranges from 0 to 11.
#           2.we also observe Automatic transmission car selling price ranges from 1 to 11.

# %%
sns.catplot(x="milage/kmpl", y="car condition (as per Kms_Driven)", data=veh)

# %% [markdown]
# Inference:1.By seeing this we can say that, old cars gives milage between 12 to 25.
#           2. we also observe new cars gives milage between 21 to 25 kmpl.

# %%
sns.catplot(x="Year", y="Kms_Driven", data=veh)

# %%
Inference:1.we observe by seeing this plot is we specify car condition as per Kms_Driven.
          2.2018 model car condition is much better as compared to other cars because it is very less kms driven and also 
             new model.

# %%
sns.lmplot(data=veh, x="Year", y="Present_Price", hue="Owner")

# %% [markdown]
# Inference:1 By seeing this we can observe that, both old new car model is between 2009 to 2018.
