# %%
#Importing Python Modules Pandas, Numpy, Seaborn, Matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Loading Medical Insurance dataset into variable df by using pandas
df = pd.read_csv("F:\Data Science Course\Joyita\Medical Insurance - R\insurance.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#To view first 5 rows of the dataset
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Inference:
# In this data sheet; Age, Sex, BMI, Children, Smoker and Region are independent objects and Charge is the Dependent object which is depending on all the previous mentioned objects.

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.relplot(x="age", y="charges", data = df)
plt.savefig("img_10")

# %% [markdown]
# Inference:
# - By seeing this visualisation, we can say that more number of people are getting medical charges in 2 groups: 1st between 0- 5000 and 2nd between 12000-25000.
# - Also we can see that most of the people are getting medical charges are divided into 3 groups: 1st between 0-5000, 2nd between 12000-20000, 3rd between 33000-40000.

# %%
sns.relplot(x="age", y="charges", data = df, hue="children")
plt.savefig("img_11")

# %% [markdown]
# Inference:
# By seeing this visualisation, we can say that most of the people don't have children and least number of people have 6 children.

# %%
sns.relplot(x="age", y="charges", data = df, hue="smoker")
plt.savefig("img_12")

# %% [markdown]
# Inference:
# - by seeing this visualisation, we can say that smokers are getting more medical charges compared to non-smokers, ie. they are more prone to diseases.
# - Most of the smokers are getting medical charges between 32000-40000 and most of the non-smokers are getting between 0-10000.

# %%
sns.catplot(x="region", y="charges", data=df)

# %% [markdown]
# Inference:
# - by seeing this visualisation, we can say that more number are claiming for medical charges in southeast region compared to others.
# - Also, most of the people are claiming medical charges between 0-10000 and number of people claiming more medical charges is decreasing gradually in all the regions.

# %%
sns.catplot(x="children", y="charges", data=df)
plt.savefig("img_16")

# %% [markdown]
# Inference:
# by seeing this visualisation, we can observe that the amount of individual medical cost billed by health insurance is reducing with increase in number of children.

# %%
sns.catplot(x="sex", y="charges", data=df)

# %% [markdown]
# Inference:
# by seeing this visualisation, we can say that number of male smokers are more compared to female smokers.

# %%
sns.catplot(x="smoker", y="charges", data=df)

# %% [markdown]
# Inference:
# - by seeing this visualisation, we can say that most of smokers are getting medical charges between 15000-22000, 32000-49000 and most of non-smokers are getting between 0-15000
# - smokers are more likely to diseases than non-smokers.

# %%
sns.catplot(x="smoker", y="charges", data=df, kind="box")
plt.savefig("img_13")

# %% [markdown]
# Inference:
# - by seeing this visualisation, we can observe that most of the smokers are getting medical cost billed by health insurance between 20000-40000 whereas most of the non-smokers are getting medical charges between 0-10000.
# - we can conclude that individual medical cost billed by health insurance is more for smokers compared to non-smokers.

# %%
sns.catplot(x="region", data=df, kind="count")

# %% [markdown]
# Inference:
# by seeing this visualisation, we can say that people claiming medical insurance are almost same in all the regions, but are maximum in southeast region.

# %%
sns.catplot(x="children", data=df, kind="count")
plt.savefig("img_14")

# %% [markdown]
# Inference:
# - by seeing this visualisation, we can say that number of people with more number of children is inversely proportional to number of children
# - maximum people don't have children and least number of people have 5 children.

# %%
sns.boxenplot(data=df, x="bmi")

# %% [markdown]
# Inference:
# by seeing this visualisation, we can say that most of the people claimling for medical charges have BMI between 26-35.

# %%
sns.boxenplot(data=df, x="charges")

# %% [markdown]
# Inference:
# by seeing this visualisation, we can say that most of the people are getting medical charges between 5000-17000.

# %%
sns.set(style="whitegrid")
sns.distplot(df["charges"])

# %% [markdown]
# Inference:
# - by seeing this visualisation, we can say that most of the people are getting medical insurance between 2000-13000
# - maximum are getting 5000 medical charge.

# %%
sns.set_color_codes()
sns.distplot(df["bmi"], color="m")

# %% [markdown]
# Inference:
# - by seeing this visualisation we can say that most of the people claiming medical insurance are having BMI between 22-37
# - maximum people have BMI=30.

# %%
sns.lmplot(data=df, x="bmi", y="charges", hue="smoker")
plt.savefig("img_15")

# %% [markdown]
# Inference:
# - by seeing this visualisation graph we can say that, most of the people are having BMI between 22-37
# - they are getting medical charges between 0-10000
# - all of them are non-smokers.

# %%
def age(x):
    if(x > 15 and x <= 30):
        return "Youth"
    elif(x > 30 and x <= 45):
        return "Adult"
    elif(x > 45 and x <= 60):
        return "Middle Aged"
    else:
        return "Old Age"

# %%
df["Age_Groups"] = df["age"].apply(lambda x: age(x))
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#        Age_Groups
# 0           Youth
# 1           Youth
# 2           Youth
# 3           Adult
# 4           Adult
# ...           ...
# 1333  Middle Aged
# ...

# %%
def bmi(y):
    if(y > 18.5 and y < 25):
        return "Ideal"
    elif(y <= 18.5):
        return "Underweight"
    elif(y >= 25):
        return "Overweight"

# %%
df["BMI_Range"] = df["bmi"].apply(lambda y : bmi(y))
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#        Age_Groups   BMI_Range
# 0           Youth  Overweight
# 1           Youth  Overweight
# 2           Youth  Overweight
# 3           Adult       Ideal
# ...

# %%
#To add the new columns to the parent Data Set in the CSV File
df.to_csv("F:/Data Science Course/Joyita/Medical Insurance - R/test_insurance.csv")

# %%
ds = pd.read_csv("F:/Data Science Course/Joyita/Medical Insurance - R/test_insurance.csv")
ds.head()
# Out:
#    Unnamed: 0  age     sex     bmi  children smoker     region      charges  \
# 0           0   19  female  27.900         0    yes  southwest  16884.92400
# 1           1   18    male  33.770         1     no  southeast   1725.55230
# 2           2   28    male  33.000         3     no  southeast   4449.46200
# 3           3   33    male  22.705         0     no  northwest  21984.47061
# 4           4   32    male  28.880         0     no  northwest   3866.85520
#
#   Age_Groups   BMI_Range
# 0      Youth  Overweight
# 1      Youth  Overweight
# 2      Youth  Overweight
# 3      Adult       Ideal
# 4      Adult  Overweight

# %%
ds.drop("Unnamed: 0", axis=1, inplace=True)
ds.head()
# Out:
#    age     sex     bmi  children smoker     region      charges Age_Groups  \
# 0   19  female  27.900         0    yes  southwest  16884.92400      Youth
# 1   18    male  33.770         1     no  southeast   1725.55230      Youth
# 2   28    male  33.000         3     no  southeast   4449.46200      Youth
# 3   33    male  22.705         0     no  northwest  21984.47061      Adult
# 4   32    male  28.880         0     no  northwest   3866.85520      Adult
#
#     BMI_Range
# 0  Overweight
# 1  Overweight
# 2  Overweight
# 3       Ideal
# 4  Overweight

# %%
sns.catplot(x="Age_Groups", y="charges", data = ds, kind="box")
plt.savefig("img_17")

# %% [markdown]
# Inference:
# - by seeing this graph, we can say that maximum charges are claimed by old age people (15000-28000). That means old aged people are more prone to diseases or loss of life
# - youth are claiming charges between 3000-16000
# - Adults are claiming charges between 7000-17000
# - Middle-aged people are claiming charges between 10000-20000

# %%
sns.catplot(x="BMI_Range", y="charges", data = ds, kind= "box")
plt.savefig("img_18")

# %% [markdown]
# Inference:
# - By visualising this graph, we can say that Maximum medical charges are claimed by over-weight people (5000-18000)
# - least medical charges are claimed by under-weight people(2000-12000)
# - maximum people in this dataset are over-weight.
